# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx"
df = pd.read_excel(url, sheet_name='Canada by Citizenship', skiprows=range(20), skipfooter=2)
df.tail()
# Out:
#            Type    Coverage          OdName  AREA AreaName  REG  \
# 190  Immigrants  Foreigners        Viet Nam   935     Asia  920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa  912
# 192  Immigrants  Foreigners           Yemen   935     Asia  922
# 193  Immigrants  Foreigners          Zambia   903   Africa  910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa  910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 190  South-Eastern Asia  902  Developing regions  1191  ...  1816  1852  3153
# 191     Northern Africa  902  Developing regions     0  ...     0     0     1
# 192        Western Asia  902  Developing regions     1  ...   124   161   140
# 193      Eastern Africa  902  Developing regions    11  ...    56    91    77
# 194      Eastern Africa  902  Developing regions    72  ...  1450   615   454
#
#      2007  2008  2009  2010  2011  2012  2013
# 190  2574  1784  2171  1942  1723  1731  2112
# ...

# %%
df.drop(columns=['Type', 'Coverage', 'DEV', 'AREA', 'REG'], inplace=True)

# %%
df.rename(columns={ 'OdName' : 'Country', 'AreaName' : 'Continent' }, inplace=True)

# %%
df.rename(columns={ 'OdName' : 'Country', 'AreaName' : 'Continent' }, inplace=True)

# %%
df[df['Country'] == 'India']
# Out:
#    Country Continent        RegName             DevName  1980  1981  1982  \
# 79   India      Asia  Southern Asia  Developing regions  8880  8670  8147
#
#     1983  1984  1985  ...   2004   2005   2006   2007   2008   2009   2010  \
# 79  7338  5704  4211  ...  28235  36210  33848  28742  28261  29456  34235
#
#      2011   2012   2013
# 79  27509  30933  33087
#
# [1 rows x 38 columns]

# %%
df[df['Continent'] == 'Asia']
# Out:
#                                             Country Continent  \
# 0                                       Afghanistan      Asia
# 8                                           Armenia      Asia
# 11                                       Azerbaijan      Asia
# 13                                          Bahrain      Asia
# 14                                       Bangladesh      Asia
# 20                                           Bhutan      Asia
# 25                                Brunei Darussalam      Asia
# 30                                         Cambodia      Asia
# 36                                            China      Asia
# 37   China, Hong Kong Special Administrative Region      Asia
# 38       China, Macao Special Administrative Region      Asia
# 46                                           Cyprus      Asia
# 48            Democratic People's Republic of Korea      Asia
# 66                                          Georgia      Asia
# ...

# %%
df[df['Continent']=='Asia']["years"].sort_values(2013,ascending=False).head(10).T.plot(figsize=14,6))
plt.xticks(size=12,rotation=30)
plt.yticks(size=12)
plt.show()
# Out:
#   Input In [41]
#     df[df['Continent']=='Asia']["years"].sort_values(2013,ascending=False).head(10).T.plot(figsize=14,6))
#                                                                                                        ^
# SyntaxError: positional argument follows keyword argument

# %%
df[[2010,2012,2013]].T.plot()
# Out:
# <AxesSubplot:>

# %%
years = list(range(1980, 2014))
years
# Out:
# [1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013]

# %%
df[years].sum().plot(kind='bar',figsize=(15,6))
# Out:
# <AxesSubplot:>

# %%
df[df['Continent']=='Europe'][years].sort_values(2010,ascending=False)[2010].head(10).plot(kind='bar',figsize=(12,8))
plt.title('Top 10 countries of Europe in immigration count in 2010')
plt.xlabel('countries')
plt.ylabel('Immigration count')
plt.show()

# %%
df['total']= df.sum(axis=1)
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_8316\2378947913.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['total']= df.sum(axis=1)

# %%
df.groupby('Continent').sum()['total']
# Out:
# Continent
# Africa                              618948
# Asia                               3317794
# Europe                             1410947
# Latin America and the Caribbean     765148
# Northern America                    241142
# Oceania                              55174
# Name: total, dtype: int64

# %%
Continent.plot(kind="pie")
plt.title('Total Continents contribution to immigeration')
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\sachi\digi da\data analitics\visualsingData.ipynb Cell 15' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sachi/digi%20da/data%20analitics/visualsingData.ipynb#ch0000014?line=0'>1</a> Continent.plot(kind="pie")
#       <a href='vscode-notebook-cell:/c%3A/Users/sachi/digi%20da/data%20analitics/visualsingData.ipynb#ch0000014?line=1'>2</a> plt.title('Total Continents contribution to immigeration')
#       <a href='vscode-notebook-cell:/c%3A/Users/sachi/digi%20da/data%20analitics/visualsingData.ipynb#ch0000014?line=2'>3</a> plt.show
#
# NameError: name 'Continent' is not defined
